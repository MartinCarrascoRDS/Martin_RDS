# %% [markdown]
# # EDICIÓN DE REPORTES EN GENERAL PARA HACER INFORMES EN POWER BI

# %%
import pandas as pd

# %%
from pipeline.procesamiento_bases import procesar_para_powerBI

# %%
path_csv = '/Users/martincarrasco/Desktop/Martín_Carrasco/Reportes/2024/Mercado de Repuestos/Ventas mercado de repuestos 2024.csv'
año = 2024

# %%
repuestos_2024 = pd.read_csv('/Users/martincarrasco/Desktop/Martín_Carrasco/Reportes/2024/Mercado de Repuestos/Ventas mercado de repuestos 2024.csv')
repuestos_2024['Periodo.Mes'].unique()
# Out:
# /var/folders/lr/rkgxn4r50h712qndyykwjmfh0000gp/T/ipykernel_2549/3147867694.py:1: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   repuestos_2024 = pd.read_csv('/Users/martincarrasco/Desktop/Martín_Carrasco/Reportes/2024/Mercado de Repuestos/Ventas mercado de repuestos 2024.csv')
# array(['7 604 770', '1', '4', '7', '5', '3', '6', '8', '2', '11', '9',
#        '12', '10', 7, 4, 8, 5, 6, 2, 1, 3, 12, 9, 10, 11], dtype=object)

# %%
repuestos_2024 = procesar_para_powerBI(path_csv, año)
repuestos_2024
# Out:
# /Users/martincarrasco/Desktop/Martín_Carrasco/pipeline/pipeline/procesamiento_bases.py:218: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path_csv)
#                                          Producto          Marca  \
# 1         Ampolleta Led Headlight H1 H3 H4 H7 H11  DE TODO Y MÁS
# 2        Kit Turbo Led H1 H3 H4 H7 H11 H13 9005 9           FOCO
# 3        Kit Turbo Led H1 H3 H4 H7 H11 H13 9005 9           FOCO
# 4        Kit Turbo Led H1 H3 H4 H7 H11 H13 9005 9           FOCO
# 5         Kit Luces Turbo Led R12. 280w 28.000 Lm            R12
# ...                                           ...            ...
# 1165406   Parachoque Del Suzuki Alto K10 1.0 K10b   ALTERNATIVAS
# 1165407  Carburador Toyota Corolla 1.3 2e Con Aho          KINZO
# 1165408  Cremallera Direccion Peugeot 307 1600 Dv   BHORKE-CHINA
# 1165409     Foco Trasero Izquierdo Jac X200 Nuevo      SIN MARCA
# ...

# %%
path_csv = '/Users/martincarrasco/Desktop/Martín_Carrasco/Reportes/2025/Mercado de Repuestos/Ventas mercado de repuestos 2025 (hasta 22-06).csv'
año = 2025

# %%
repuestos_2025 = procesar_para_powerBI(path_csv, año)
repuestos_2025
# Out:
# /Users/martincarrasco/Desktop/Martín_Carrasco/pipeline/pipeline/procesamiento_bases.py:218: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path_csv)
#                                         Producto     Marca  \
# 1       Gas Refrigerante R-134a, Para Aire Acond    GLOBAL
# 2       Gas Refrigerante R-134a, Para Aire Acond    GLOBAL
# 3       Kit Turbo Led Canbus H1 H3 H4 H7 H11 900      FOCO
# 4       Kit Turbo Led H1 H3 H4 H7 H11 H13 9005 9     KERUI
# 5       Kit Turbo Led H1 H3 H4 H7 H11 H13 9005 9      FOCO
# ...                                          ...       ...
# 653875             Soporte De Motor Izquierdo F0       BYD
# 653876   Farol Esquinero Izq Para Hyundai Porter  GENÉRICO
# 653877   Espejo De Maquillaje De Visera De Coche  SHUANG.W
# 653878  Jgo. Bujías Mopar Original Jeep Grand Ch     MOPAR
# 653879       Barra De Dirección Kyc X5 Y X5 Plus       KYC
#
# ...

# %%
repuestos_2024_2025 = pd.concat([repuestos_2024, repuestos_2025], ignore_index = True)

# %%
ruta_salida = '/Users/martincarrasco/Desktop/Martín_Carrasco/Reportes/Interanuales/Mercado de Repuestos/Ventas mercado de repuestos 2024-2025 (hasta 22-06-2025).csv'
repuestos_2024_2025.to_csv(ruta_salida, index = False, encoding='utf-8-sig')
