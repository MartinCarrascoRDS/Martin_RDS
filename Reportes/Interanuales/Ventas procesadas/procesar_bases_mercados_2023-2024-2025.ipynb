# %% [markdown]
# # NOTEBOOK PARA PROCESAR BASES DE DATOS DE VENTAS EN MERCADOS

# %% [markdown]
# ## UNIÓN ENTRE BASES 2023, 2024 Y 2025

# %%
import pandas as pd

# %%
# Recordar: las fechas para estas bases de datos están en formato 'DD-MM-YYYY'

# %%
# Ventas 2023
path_ventas_2023 = '/Users/martincarrasco/Desktop/Martín_Carrasco/Reportes/2023/Ventas procesadas/Ventas accesorios-lubricantes-neumaticos-repuestos 2023.csv'
ventas_2023 = pd.read_csv(path_ventas_2023, sep = ",", encoding = 'utf-8')

# Ventas 2024
path_ventas_2024 = '/Users/martincarrasco/Desktop/Martín_Carrasco/Reportes/2024/Ventas procesadas/Ventas accesorios-lubricantes-neumaticos-repuestos 2024.csv'
ventas_2024 = pd.read_csv(path_ventas_2024, sep=',', encoding='utf-8')

# Ventas 2025 (hasta 20-07)
path_ventas_2025 = '/Users/martincarrasco/Desktop/Martín_Carrasco/Reportes/2025/Ventas procesadas/ventas accesorios-lubricantes-neumaticos-repuestos 2025.csv'
ventas_2025 = pd.read_csv(path_ventas_2025, sep=',', encoding='utf-8')

# %%
ventas_2023_2024_2025 = pd.concat([ventas_2023, ventas_2024, ventas_2025], ignore_index=True)
ventas_2023_2024_2025.to_csv('/Users/martincarrasco/Desktop/Martín_Carrasco/Reportes/Interanuales/Ventas procesadas/ventas accesorios-lubricantes-neumaticos-repuestos 2023-2024-2025.csv', index=False, encoding='utf-8')

# %%
ventas_2023_2024_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3746628 entries, 0 to 3746627
# Data columns (total 11 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Producto           object
#  1   Mercado            object
#  2   Marca              object
#  3   Categoría          object
#  4   Subcategoría       object
#  5   Año                int64
#  6   Mes                int64
#  7   Fecha venta        object
#  8   Seller             object
#  9   Unidades_Vendidas  int64
#  10  Ventas             int64
# dtypes: int64(4), object(7)
# memory usage: 314.4+ MB
