# %% [markdown]
# # NOTEBOOK PARA PROCESAR BASES DE DATOS DE VENTAS EN MERCADOS DURANTE 2024-2025 (hasta 13-07-2025)

# %% [markdown]
# ## UNIÓN ENTRE BASES 2024 Y 2025 HASTA 13-07

# %%
import pandas as pd

# %%
# Ventas 2024
path_ventas_2024 = '/Users/martincarrasco/Desktop/Martín_Carrasco/Reportes/2024/Ventas procesadas/Ventas accesorios-lubricantes-neumaticos-repuestos 2024.csv'
ventas_2024 = pd.read_csv(path_ventas_2024, sep=',', encoding='utf-8')

# Ventas 2025 (hasta 20-07)
path_ventas_2025 = '/Users/martincarrasco/Desktop/Martín_Carrasco/Reportes/2025/Ventas procesadas/ventas accesorios-lubricantes-neumaticos-repuestos 2025 (hasta 10-08).csv'
ventas_2025 = pd.read_csv(path_ventas_2025, sep=',', encoding='utf-8')

# %%
ventas_2024_2025 = pd.concat([ventas_2024, ventas_2025], ignore_index=True)
ventas_2024_2025.to_csv('/Users/martincarrasco/Desktop/Martín_Carrasco/Reportes/Interanuales/Ventas procesadas/ventas accesorios-lubricantes-neumaticos-repuestos 2024-2025 (hasta 10-08-2025).csv', index=False, encoding='utf-8')

# %%
ventas_2024_2025
# Out:
#                                          Producto     Mercado Proveedor  \
# 0        Carpa Funda Cubre Auto Suv Premium Con F  Accesorios         -
# 1        Carpa Funda Cubre Auto Suv Premium Con F  Accesorios         -
# 2        Carpa Funda Cubre Auto Suv Premium Con F  Accesorios         -
# 3        Carpa Funda Cubre Auto Suv Premium Con F  Accesorios         -
# 4        Fundas Cubreasiento B-equip Ecocuero Neg  Accesorios         -
# ...                                           ...         ...       ...
# 2290584   Espejo De Maquillaje De Visera De Coche   Repuestos         -
# 2290585       Barra De Dirección Kyc X5 Y X5 Plus   Repuestos         -
# 2290586             Soporte De Motor Izquierdo F0   Repuestos         -
# 2290587  Sensor Presión Aire Acondicionado Para C   Repuestos         -
# 2290588  Jgo. Bujías Mopar Original Jeep Grand Ch   Repuestos         -
#
#                       SKU          Marca               Categoría  \
# 0                (blanco)  TECNOTIENDARR  Accesorios de Exterior
# 1                (blanco)  TECNOTIENDARR  Accesorios de Exterior
# 2                (blanco)  TECNOTIENDARR  Accesorios de Exterior
# 3                (blanco)  TECNOTIENDARR  Accesorios de Exterior
# 4                (blanco)        B-EQUIP  Accesorios de Interior
# ...                   ...            ...                     ...
# 2290584         OBEK45956       SHUANG.W   Repuestos de Interior
# 2290585          (blanco)            KYC  Suspensión y Dirección
# 2290586              1105            BYD                 Motores
# 2290587  GENLY240607LXY15     GENOVATION           Climatización
# 2290588        68303913AA          MOPAR               Encendido
#
#                  Subcategoría   Año  Mes Fecha venta  \
# 0                  Cobertores  2024   10  2024-10-01
# 1                  Cobertores  2024    9  2024-09-01
# 2                  Cobertores  2024    8  2024-08-01
# 3                  Cobertores  2024   11  2024-11-01
# 4              Cubre Asientos  2024    8  2024-08-01
# ...                       ...   ...  ...         ...
# 2290584               Viseras  2025    6  2025-06-01
# 2290585       Barras y Piezas  2025    2  2025-02-01
# 2290586     Soportes de Motor  2025    6  2025-06-01
# 2290587  Aires Acondicionados  2025    7  2025-07-01
# 2290588                Bujías  2025    6  2025-06-01
#
#                                    Seller  Unidades_Vendidas    Ventas  \
# 0              salamandra.plata.pictorico                793  15852070
# 1              salamandra.plata.pictorico                753  15052470
# 2              salamandra.plata.pictorico                673  13949270
# 3              salamandra.plata.pictorico                684  13673160
# 4                  secretario.jade.peleon                343  11012599
# ...                                   ...                ...       ...
# 2290584       calao.amelocotonado.luminar                  2         0
# 2290585                       ROGU5895488                  1         0
# 2290586  marsupial.abigarrado.demografico                  1         0
# 2290587           lemming.anacardo.fragil                  1         0
# 2290588           ASTARA REPUESTOSEXPRESS                  1         0
#
#          Cancelaciones
# 0               259870
# 1                99950
# 2               273870
# 3                39980
# 4                99877
# ...                ...
# 2290584              0
# 2290585              0
# 2290586              0
# 2290587              0
# 2290588              0
#
# [2290589 rows x 14 columns]

# %%
ventas_2024_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290589 entries, 0 to 2290588
# Data columns (total 14 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Producto           object
#  1   Mercado            object
#  2   Proveedor          object
#  3   SKU                object
#  4   Marca              object
#  5   Categoría          object
#  6   Subcategoría       object
#  7   Año                int64
#  8   Mes                int64
#  9   Fecha venta        object
#  10  Seller             object
#  11  Unidades_Vendidas  int64
#  12  Ventas             int64
#  13  Cancelaciones      int64
# dtypes: int64(5), object(9)
# memory usage: 244.7+ MB

# %%
ventas_2024_2025.groupby('Fecha venta')['Ventas'].sum()
# Out:
# Fecha venta
# 2024-01-01    10659701295
# 2024-02-01     9332939814
# 2024-03-01     9195821405
# 2024-04-01     9455310242
# 2024-05-01     9043346758
# 2024-06-01     9144952905
# 2024-07-01     9905379857
# 2024-08-01     9815122652
# 2024-09-01     8894849847
# 2024-10-01    10405479412
# 2024-11-01     9893767313
# 2024-12-01     9579070957
# 2025-01-01    11802976037
# 2025-02-01    10477284576
# 2025-03-01    11917660311
# 2025-04-01    11180248828
# 2025-05-01    11331708853
# 2025-06-01    11868037250
# 2025-07-01    12290303574
# 2025-08-01     3834674179
# Name: Ventas, dtype: int64

# %%
ventas_2024_2025['Mercado'].unique()
# Out:
# array(['Accesorios', 'Lubricantes', 'Neumáticos', 'Repuestos'],
#       dtype=object)

# %%
ventas_2024_2025['Proveedor'].unique()
# Out:
# array(['-', 'BICIMOTO', 'CUATRO RUEDAS', 'REFAX', 'MANNHEIM', 'ALSACIA',
#        'MATSUMOTO', 'NEUMACHILE', 'BODEGA', 'IMASA', 'MEC', 'AUTOMARCO',
#        'NORIEGA', 'EMASA', 'ITALFRENOS', 'GABTEC', 'AUTOTEC'],
#       dtype=object)

# %%
ventas_2024_2025[ventas_2024_2025['Seller'] == 'REPUESTOS DEL SOL']
# Out:
#                                          Producto     Mercado Proveedor  \
# 499       Tapa Rueda Chevrolet Sail 1.4 2011 2016  Accesorios         -
# 699       Tapa Rueda Chevrolet Sail 1.4 2011 2016  Accesorios         -
# 715       Tapa Rueda Chevrolet Sail 1.4 2011 2016  Accesorios         -
# 739       Tapa Rueda Chevrolet Sail 1.4 2011 2016  Accesorios         -
# 1075      Tapa Rueda Chevrolet Sail 1.4 2011 2016  Accesorios         -
# ...                                           ...         ...       ...
# 2277129  Filtro Cabina Para Nissan Np300 2.3 Ys23   Repuestos     REFAX
# 2277131  Filtro Bencina Para Renault Clio 1.6 K7m   Repuestos     REFAX
# 2277137  Filtro Aire Para Nissan Navara 2.5 Yd25d   Repuestos     REFAX
# 2277139  Filtro Aceite Para Nissan Kicks 1.6 Hr16   Repuestos     REFAX
# 2277145  Kit Buje Punta Barra Estabilizadora Para   Repuestos  MANNHEIM
#
#                      SKU     Marca               Categoría  \
# 499             (blanco)  GENÉRICO  Accesorios de Exterior
# 699             (blanco)       CIB  Accesorios de Exterior
# 715             (blanco)  GENÉRICO  Accesorios de Exterior
# 739             (blanco)  GENÉRICO  Accesorios de Exterior
# 1075            (blanco)  GENÉRICO  Accesorios de Exterior
# ...                  ...       ...                     ...
# 2277129        RX9954078    WURTEX                 Filtros
# 2277131        RXF000730    WURTEX                 Filtros
# 2277137        RX0021079    WURTEX                 Filtros
# 2277139        RX9953853    WURTEX                 Filtros
# 2277145  FMA0014542205X4  GENÉRICO  Suspensión y Dirección
#
#                Subcategoría   Año  Mes Fecha venta             Seller  \
# 499          Tapas de Rueda  2024    3  2024-03-01  REPUESTOS DEL SOL
# 699          Tapas de Rueda  2024   10  2024-10-01  REPUESTOS DEL SOL
# 715          Tapas de Rueda  2024    2  2024-02-01  REPUESTOS DEL SOL
# 739          Tapas de Rueda  2024    4  2024-04-01  REPUESTOS DEL SOL
# 1075         Tapas de Rueda  2024    1  2024-01-01  REPUESTOS DEL SOL
# ...                     ...   ...  ...         ...                ...
# 2277129    Filtros de Polen  2025    1  2025-01-01  REPUESTOS DEL SOL
# 2277131  Filtros de Bencina  2025    7  2025-07-01  REPUESTOS DEL SOL
# 2277137     Filtros de Aire  2025    2  2025-02-01  REPUESTOS DEL SOL
# 2277139   Filtros de Aceite  2025    3  2025-03-01  REPUESTOS DEL SOL
# 2277145               Bujes  2025    2  2025-02-01  REPUESTOS DEL SOL
#
#          Unidades_Vendidas   Ventas  Cancelaciones
# 499                     62  1820480          57980
# 699                     71  1490290          20990
# 715                     51  1462230              0
# 739                     50  1440800              0
# 1075                    43  1167570              0
# ...                    ...      ...            ...
# 2277129                  1     4990              0
# 2277131                  1     4990              0
# 2277137                  1     4990              0
# 2277139                  1     4990              0
# 2277145                  1     4990              0
#
# [53877 rows x 14 columns]
