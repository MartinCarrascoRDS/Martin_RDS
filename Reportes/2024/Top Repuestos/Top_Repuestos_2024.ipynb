# %% [markdown]
# # VENTAS TOP REPUESTOS 2024

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import openpyxl
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Fuente de datos
ventas_tr = pd.read_excel('/Users/martincarrasco/Desktop/Martín Carrasco/Reportes/2024/Top Repuestos/Ventas Top Repuestos 2024 (2).xlsx', skiprows = 2)
ventas_tr
# Out:
#                                     Unnamed: 0 Unnamed: 1  \
# 0                           Titulo_Publicacion      Marca
# 1                                          NaN        NaN
# 2     Filtro Particulas Dpf Nissan Navara 08/1    GABRIEL
# 3      Filtro Particulas Dpf Chevrolet Captiva    GABRIEL
# 4     Par Amortiguadores Delanteros Toyota Hil    GABRIEL
# ...                                        ...        ...
# 7173  Plumilla  1   Universal 20 PuLG. Grafita    ULTRA X
# 7174  Plumilla  1   Universal 15 PuLG. Grafita    ULTRA X
# 7175  Plumilla  1   Universal 15 PuLG. Grafita    ULTRA X
# 7176  Plumilla  1   Universal 15 PuLG. Grafita    ULTRA X
# 7177  Ampolleta 12v 21/5w Bay15d P/d 10 Unidad    FLOSSER
#
#                   Unnamed: 2                  Unnamed: 3   Unnamed: 4  \
# 0                     level3                      level4  Periodo.Mes
# 1                        NaN                         NaN        39562
# ...
