# %% [markdown]
# # NOTEBOOK PARA LA UNIÓN DE VENTAS 2023 POR MERCADO

# %%
import pandas as pd

# %%
path1 = '/Users/martincarrasco/Desktop/Martín_Carrasco/Reportes/2023/Ventas procesadas/Ventas accesorios-lubricantes-neumaticos-repuestos 2023 (hasta 31-03).csv'
path2 = '/Users/martincarrasco/Desktop/Martín_Carrasco/Reportes/2023/Ventas procesadas/Ventas accesorios-lubricantes-neumaticos-repuestos 2023 (01-04 al 31-12).csv'
df1 = pd.read_csv(path1, sep = ",")
df2 = pd.read_csv(path2, sep = ",")
df = pd.concat([df1, df2], ignore_index = True)
df.to_csv('/Users/martincarrasco/Desktop/Martín_Carrasco/Reportes/2023/Ventas procesadas/Ventas accesorios-lubricantes-neumaticos-repuestos 2023.csv', index = False, encoding = 'utf-8')
