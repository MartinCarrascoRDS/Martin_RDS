# %% [markdown]
# # Adaptación de base de datos: Ventas de mercado de Repuestos 2025 (hasta 13-07)

# %%
import pandas as pd
from pipeline.procesamiento.procesamiento_bases import procesar_para_powerBI

# %%
path_csv = 'C:/Users/marti/OneDrive/Documents/Martin_RDS/Reportes/2025/Mercado de Repuestos/Ventas mercado de repuestos 2025 (hasta 13-07).csv'

# %%
repuestos_2025 = procesar_para_powerBI(path_csv, año = 2025, fecha_ultima_venta = '2025-07-13', mercado = 'Repuestos')
repuestos_2025
# Out:
# C:\Users\marti\OneDrive\Documents\Martin_RDS\recursos_proyectos\pipeline\procesamiento\procesamiento_bases.py:254: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path_csv, skiprows = header_line, sep = sep)
#                                         Producto       Marca  \
# 1       Gas Refrigerante R-134a, Para Aire Acond      GLOBAL
# 2       Kit Turbo Led Canbus H1 H3 H4 H7 H11 900        FOCO
# 3       Gas Refrigerante R-134a, Para Aire Acond      GLOBAL
# 4       Kit Turbo Led Canbus H1 H3 H4 H7 H11 900        FOCO
# 5       Kit Turbo Led H1 H3 H4 H7 H11 H13 9005 9       KERUI
# ...                                          ...         ...
# 743083   Espejo De Maquillaje De Visera De Coche    SHUANG.W
# 743084  Jgo. Bujías Mopar Original Jeep Grand Ch       MOPAR
# 743085   Farol Esquinero Izq Para Hyundai Porter    GENÉRICO
# 743086       Barra De Dirección Kyc X5 Y X5 Plus         KYC
# ...
