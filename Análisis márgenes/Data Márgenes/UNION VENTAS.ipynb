# %% [markdown]
# # UNIÓN VENTAS

# %%
import pandas as pd
import os

año = int(input('Indica el año que corresponde a las ventas que quieres unir: '))
fecha = input('Indica la fecha que corresponde a las ventas que quieres unir: ')

# %%
output_folder = f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}'
os.makedirs(output_folder, exist_ok = True)

# %%
# Ingresos totales

autosol = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/AUTOSOL {fecha} Ingresos totales.xlsx', dtype = {"# de venta": str})
bicisol = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/BICISOL {fecha} Ingresos totales.xlsx', dtype = {"# de venta": str})
blackparts = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/BLACKPARTS {fecha} Ingresos totales.xlsx', dtype = {"# de venta": str})
hyundai = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/HYUNDAI {fecha} Ingresos totales.xlsx', dtype = {"# de venta": str})
indusol = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/INDUSOL {fecha} Ingresos totales.xlsx', dtype = {"# de venta": str})
mercadorepuestos = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/MERCADOREPUESTOS {fecha} Ingresos totales.xlsx', dtype = {"# de venta": str})
rds1 = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/RDS1 {fecha} Ingresos totales.xlsx', dtype = {"# de venta": str})
rds3 = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/RDS3 {fecha} Ingresos totales.xlsx', dtype = {"# de venta": str})
reicars = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/REICARS {fecha} Ingresos totales.xlsx', dtype = {"# de venta": str})
triana = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/TRIANA {fecha} Ingresos totales.xlsx', dtype = {"# de venta": str})
tyc = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/TYC {fecha} Ingresos totales.xlsx', dtype = {"# de venta": str})

dfs = [autosol, bicisol, blackparts, hyundai, indusol, mercadorepuestos, rds1, rds3, reicars, triana, tyc]

df_consolidado = pd.concat(dfs, ignore_index = True)
df_consolidado.to_excel(f'{output_folder}/CONSOLIDADO {fecha} INGRESOS TOTALES.xlsx', index = False)

# %%
# Ventas en paquete

autosol = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/AUTOSOL {fecha} Ventas en paquete.xlsx', dtype = {"# de venta": str})
bicisol = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/BICISOL {fecha} Ventas en paquete.xlsx', dtype = {"# de venta": str})
blackparts = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/BLACKPARTS {fecha} Ventas en paquete.xlsx', dtype = {"# de venta": str})
hyundai = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/HYUNDAI {fecha} Ventas en paquete.xlsx', dtype = {"# de venta": str})
indusol = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/INDUSOL {fecha} Ventas en paquete.xlsx', dtype = {"# de venta": str})
mercadorepuestos = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/MERCADOREPUESTOS {fecha} Ventas en paquete.xlsx', dtype = {"# de venta": str})
rds1 = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/RDS1 {fecha} Ventas en paquete.xlsx', dtype = {"# de venta": str})
rds3 = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/RDS3 {fecha} Ventas en paquete.xlsx', dtype = {"# de venta": str})
reicars = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/REICARS {fecha} Ventas en paquete.xlsx', dtype = {"# de venta": str})
triana = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/TRIANA {fecha} Ventas en paquete.xlsx', dtype = {"# de venta": str})
tyc = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/TYC {fecha} Ventas en paquete.xlsx', dtype = {"# de venta": str})

dfs = [autosol, bicisol, blackparts, hyundai, indusol, mercadorepuestos, rds1, rds3, reicars, triana, tyc]

df_consolidado = pd.concat(dfs, ignore_index = True)
df_consolidado.to_excel(f'{output_folder}/CONSOLIDADO {fecha} VENTAS EN PAQUETE.xlsx', index = False)
# Out:
# /var/folders/lr/rkgxn4r50h712qndyykwjmfh0000gp/T/ipykernel_26087/3996716072.py:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_consolidado = pd.concat(dfs, ignore_index = True)

# %%
# Ingresos sin filtrar estado

autosol = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/AUTOSOL {fecha} Ingresos sin filtrar estado.xlsx', dtype = {"# de venta": str})
bicisol = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/BICISOL {fecha} Ingresos sin filtrar estado.xlsx', dtype = {"# de venta": str})
blackparts = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/BLACKPARTS {fecha} Ingresos sin filtrar estado.xlsx', dtype = {"# de venta": str})
hyundai = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/HYUNDAI {fecha} Ingresos sin filtrar estado.xlsx', dtype = {"# de venta": str})
indusol = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/INDUSOL {fecha} Ingresos sin filtrar estado.xlsx', dtype = {"# de venta": str})
mercadorepuestos = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/MERCADOREPUESTOS {fecha} Ingresos sin filtrar estado.xlsx', dtype = {"# de venta": str})
rds1 = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/RDS1 {fecha} Ingresos sin filtrar estado.xlsx', dtype = {"# de venta": str})
rds3 = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/RDS3 {fecha} Ingresos sin filtrar estado.xlsx', dtype = {"# de venta": str})
reicars = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/REICARS {fecha} Ingresos sin filtrar estado.xlsx', dtype = {"# de venta": str})
triana = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/TRIANA {fecha} Ingresos sin filtrar estado.xlsx', dtype = {"# de venta": str})
tyc = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/TYC {fecha} Ingresos sin filtrar estado.xlsx', dtype = {"# de venta": str})

dfs = [autosol, bicisol, blackparts, hyundai, indusol, mercadorepuestos, rds1, rds3, reicars, triana, tyc]

df_consolidado = pd.concat(dfs, ignore_index = True)
df_consolidado.to_excel(f'{output_folder}/CONSOLIDADO {fecha} INGRESOS SIN FILTRAR ESTADO.xlsx', index = False)

# %%
# Ingresos con estados filtrados

autosol = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/AUTOSOL {fecha} Ingresos con estados filtrados.xlsx', dtype = {"# de venta": str})
bicisol = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/BICISOL {fecha} Ingresos con estados filtrados.xlsx', dtype = {"# de venta": str})
blackparts = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/BLACKPARTS {fecha} Ingresos con estados filtrados.xlsx', dtype = {"# de venta": str})
hyundai = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/HYUNDAI {fecha} Ingresos con estados filtrados.xlsx', dtype = {"# de venta": str})
indusol = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/INDUSOL {fecha} Ingresos con estados filtrados.xlsx', dtype = {"# de venta": str})
mercadorepuestos = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/MERCADOREPUESTOS {fecha} Ingresos con estados filtrados.xlsx', dtype = {"# de venta": str})
rds1 = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/RDS1 {fecha} Ingresos con estados filtrados.xlsx', dtype = {"# de venta": str})
rds3 = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/RDS3 {fecha} Ingresos con estados filtrados.xlsx', dtype = {"# de venta": str})
reicars = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/REICARS {fecha} Ingresos con estados filtrados.xlsx', dtype = {"# de venta": str})
triana = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/TRIANA {fecha} Ingresos con estados filtrados.xlsx', dtype = {"# de venta": str})
tyc = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/TYC {fecha} Ingresos con estados filtrados.xlsx', dtype = {"# de venta": str})

dfs = [autosol, bicisol, blackparts, hyundai, indusol, mercadorepuestos, rds1, rds3, reicars, triana, tyc]

df_consolidado = pd.concat(dfs, ignore_index = True)
df_consolidado.to_excel(f'{output_folder}/CONSOLIDADO {fecha} INGRESOS CON ESTADOS FILTRADOS.xlsx', index = False)

# %%
# Márgenes

autosol = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/AUTOSOL {fecha} Márgenes.xlsx', dtype = {"# de venta": str})
bicisol = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/BICISOL {fecha} Márgenes.xlsx', dtype = {"# de venta": str})
blackparts = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/BLACKPARTS {fecha} Márgenes.xlsx', dtype = {"# de venta": str})
hyundai = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/HYUNDAI {fecha} Márgenes.xlsx', dtype = {"# de venta": str})
indusol = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/INDUSOL {fecha} Márgenes.xlsx', dtype = {"# de venta": str})
mercadorepuestos = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/MERCADOREPUESTOS {fecha} Márgenes.xlsx', dtype = {"# de venta": str})
rds1 = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/RDS1 {fecha} Márgenes.xlsx', dtype = {"# de venta": str})
rds3 = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/RDS3 {fecha} Márgenes.xlsx', dtype = {"# de venta": str})
reicars = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/REICARS {fecha} Márgenes.xlsx', dtype = {"# de venta": str})
triana = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/TRIANA {fecha} Márgenes.xlsx', dtype = {"# de venta": str})
tyc = pd.read_excel(f'/Users/martincarrasco/Desktop/Martín_Carrasco/Análisis márgenes/Data Márgenes/{año}/{fecha}/TYC {fecha} Márgenes.xlsx', dtype = {"# de venta": str})

dfs = [autosol, bicisol, blackparts, hyundai, indusol, mercadorepuestos, rds1, rds3, reicars, triana, tyc]

df_consolidado = pd.concat(dfs, ignore_index = True)
df_consolidado.to_excel(f'{output_folder}/CONSOLIDADO {fecha} MARGENES.xlsx', index = False)
